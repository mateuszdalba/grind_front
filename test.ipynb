# %%
from camera import WebcamStream, CustomSquats
import matplotlib.pyplot as plt

# %%
video = WebcamStream()

# %%
video.start()

# %%
cust = CustomSquats()

# %%
plt.imshow(cust.process(frame_in = video.read()))
# Out:
# (720, 1280, 3)

# %%
video.stop()

# %%
plt.imshow(video.frame)
